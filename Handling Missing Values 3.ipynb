# %% [markdown]
# # Handling Missing Values

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Emp_Records.csv")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.iloc[1:2] = 5000
df.iloc[1:2] = np.nan
df.loc[1,"Salary"]
df.iloc[1,3] = np.nan
df
# Out:
#       Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509.0       Lois       36.36           60.0           13.68  168251.0
# 1        NaN        NaN         NaN            NaN             NaN       NaN
# 2   428945.0        Joe       54.15           68.0            0.98   50155.0
# 3   408351.0      Diane       39.67           51.0           18.30  180294.0
# 4   193819.0   Benjamin       40.31           58.0            4.01  117642.0
# ..       ...        ...         ...            ...             ...       ...
# 95  639892.0       Jose       22.82           89.0            1.05  129774.0
# 96  704709.0     Harold       32.61           77.0            5.93  156194.0
# 97  461593.0     Nicole       52.66           60.0           28.53   95673.0
# 98  392491.0    Theresa       29.60           57.0            6.99   51015.0
# 99  495141.0      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# ...

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1     True        True        True           True            True    True
# 2    False       False       False          False           False   False
# 3    False       False       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1    True
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isna().sum()
# Out:
# Emp ID            1
# First Name        1
# Age in Yrs        1
# Weight in Kgs     1
# Age in Company    1
# Salary            1
# City              1
# dtype: int64

# %%
df1 = pd.DataFrame(
    np.random.randint(1,50,(10,10)), index=list("ABCEDFGHIJ"),columns=list("abcdefghij")
)
df1
# Out:
#     a   b   c   d   e   f   g   h   i   j
# A  21  35  17  28  32   4  14  11  21  46
# B   6  22  44  47   3  39  38  42  42  31
# C  15  48  47  41  32  26  13  43  25  43
# E  29  46  18   5  32  22  47  42  13  36
# D  31  16  11  19  34  29   8  29  49  14
# F  37   4  30  44  32  20  21  22  29  16
# G  41  23  47   1  28   5   6  44  17  25
# H  24  29  18  21   5  14  18  38  15  43
# I   3  42  43  23  21  29  17  25  49  49
# J  49  10  27  35  34   7  46   5  18  36

# %%
df1[["d"]] == 1
# Out:
#        d
# A  False
# B  False
# C  False
# E  False
# D  False
# F  False
# G   True
# H  False
# I  False
# J  False

# %%
df.isnull()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1     True        True        True           True            True    True
# 2    False       False       False          False           False   False
# 3    False       False       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1    True
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isnull().sum()
# Out:
# Emp ID            1
# First Name        1
# Age in Yrs        1
# Weight in Kgs     1
# Age in Company    1
# Salary            1
# City              1
# dtype: int64

# %%
df = pd.read_csv("Emp_Records1.csv")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False          False           False   False
# 3    False        True       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isna().sum()
# Out:
# Emp ID             0
# First Name         6
# Age in Yrs        10
# Weight in Kgs     10
# Age in Company     9
# Salary             0
# City               6
# dtype: int64

# %%
df.isnull()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False          False           False   False
# 3    False        True       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isnull().sum()
# Out:
# Emp ID             0
# First Name         6
# Age in Yrs        10
# Weight in Kgs     10
# Age in Company     9
# Salary             0
# City               6
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      94 non-null     object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   90 non-null     float64
#  4   Age in Company  91 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %% [markdown]
# # 2. Filling Missing Values
# - filna()
#     - 1. mean()
#     - 2. median()
#     - 3. mode()
#     - 4. min()
#     - 5. max()
#     - 6. Static Value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      94 non-null     object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   90 non-null     float64
#  4   Age in Company  91 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df["Age in Yrs"].mean()
# Out:
# 38.303222222222225

# %%
df["Age in Yrs"].median()
# Out:
# 36.3

# %%
filled_df = df.fillna(100)
filled_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        100       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
filled_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df["First Name"] = df["First Name"].fillna(10000)
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      10000       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   90 non-null     float64
#  4   Age in Company  91 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df["Weight in Kgs"].fillna(33333,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   100 non-null    float64
#  4   Age in Company  91 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df["Age in Company"].mean()
# Out:
# 8.801868131868131

# %%
df["Age in Company"].fillna(8.801868131868131,inplace=True)
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      10000       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   100 non-null    float64
#  4   Age in Company  100 non-null    float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.to_csv("Check.csv")

# %%
new_df = pd.read_csv("Emp_Records1.csv")
new_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      94 non-null     object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   90 non-null     float64
#  4   Age in Company  91 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
new_df["Age in Company"].median()
# Out:
# 6.94

# %%
new_df["Age in Company"].fillna(6.94,inplace=True)
new_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      94 non-null     object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   90 non-null     float64
#  4   Age in Company  100 non-null    float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
tit_df = pd.read_csv("titanic.csv")
tit_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina     NaN  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     NaN  35.0      1
# 4                             Allen, Mr. William Henry     NaN  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           3
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tit_df["Gender"].value_counts()
# Out:
# male      576
# female    312
# Name: Gender, dtype: int64

# %%
from scipy import stats

# %%
stats.mode(tit_df["Gender"])[0][0]
# Out:
# 'male'

# %%
tit_df["Gender"].mode()
# Out:
# 0    male
# dtype: object

# %%
tit_df["Age"].min()
# Out:
# 0.42

# %%
tit_df["Age"].max()
# Out:
# 80.0

# %%
tit_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.386083    2.308642   29.699118    0.523008
# std     257.353842    0.487123    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tit_df["Age"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# #### fill na by
# - 1. mean = if there are no outliers in the col
# - 2. median = if there are outliers in the data
# - 3. mode = if the col is in the categorial manner

# %% [markdown]
# # 3. dropna

# %%
emp_test_df = pd.read_csv("Emp_Records_Test.csv")
emp_test_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_test_df.isna().sum()
# Out:
# Emp ID             0
# First Name         1
# Age in Yrs        10
# Weight in Kgs      9
# Age in Company     5
# Salary             3
# City               1
# dtype: int64

# %% [markdown]
# # 1. drop rows

# %%
demo_df = emp_test_df.dropna()

# %%
demo_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
demo_df.shape
# Out:
# (85, 7)

# %%
demo1_df = emp_test_df.dropna(thresh=7) # 7 non-null values
demo1_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# 8   477616    Frances       58.18           42.0           23.27  121587.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50           80.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#               City
# 4          Fremont
# 8          Delmita
# ...

# %%
demo2_df = emp_test_df.dropna(thresh=4) # 4 non-null values
demo2_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# 5   499687    Patrick       34.86            NaN           12.02   72305.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %% [markdown]
# # 2. drop columns

# %%
emp_test_df = pd.read_csv("Emp_Records_Test.csv")
emp_test_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_test_df.isna().sum()
# Out:
# Emp ID             0
# First Name         1
# Age in Yrs        10
# Weight in Kgs      9
# Age in Company     5
# Salary             3
# City               1
# dtype: int64

# %%
emp_test_df.dropna(axis=1)
# Out:
#     Emp ID
# 0   677509
# 1   940761
# 2   428945
# 3   408351
# 4   193819
# ..     ...
# 95  639892
# 96  704709
# 97  461593
# 98  392491
# 99  495141
#
# [100 rows x 1 columns]

# %%
emp_test_df.dropna(thresh=6,axis=1) # Min 6 non - null count
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_test_df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0  677509       Lois       36.36           60.0             NaN  168251.0
# 1  940761     Brenda         NaN            NaN            9.01   51063.0
# 2  428945        Joe         NaN           68.0             NaN   50155.0
# 3  408351      Diane         NaN            NaN             NaN       NaN
# 4  193819   Benjamin       40.31           58.0            4.01  117642.0
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
emp_test_df.dropna(thresh=95,axis=1)
# Out:
#     Emp ID First Name  Age in Company    Salary          City
# 0   677509       Lois             NaN  168251.0        Denver
# 1   940761     Brenda            9.01   51063.0     Stonewall
# 2   428945        Joe             NaN   50155.0  Michigantown
# 3   408351      Diane             NaN       NaN      Hydetown
# 4   193819   Benjamin            4.01  117642.0       Fremont
# ..     ...        ...             ...       ...           ...
# 95  639892       Jose            1.05  129774.0        Biloxi
# 96  704709     Harold            5.93  156194.0  Carol Stream
# 97  461593     Nicole           28.53   95673.0       Detroit
# 98  392491    Theresa            6.99   51015.0      Mc Grath
# 99  495141      Tammy            2.26   93650.0          Alma
#
# [100 rows x 5 columns]

# %%
demo1_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# 8   477616    Frances       58.18           42.0           23.27  121587.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50           80.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#               City
# 4          Fremont
# 8          Delmita
# ...

# %%
demo1_df.drop(["Emp ID"],axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
demo1_df
# Out:
#    First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 4    Benjamin       40.31           58.0            4.01  117642.0
# 8     Frances       58.18           42.0           23.27  121587.0
# 9       Diana       29.73           60.0            3.44   43010.0
# 10      Ralph       42.50           80.0            8.29  118457.0
# 11       Jack       22.21           61.0            0.56   82965.0
# ..        ...         ...            ...             ...       ...
# 95       Jose       22.82           89.0            1.05  129774.0
# 96     Harold       32.61           77.0            5.93  156194.0
# 97     Nicole       52.66           60.0           28.53   95673.0
# 98    Theresa       29.60           57.0            6.99   51015.0
# 99      Tammy       38.38           55.0            2.26   93650.0
#
#               City
# 4          Fremont
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas
# ..             ...
# ...

# %%
demo1_df.drop(["Age in Yrs","Salary"],axis=1,inplace=True)
demo1_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    First Name  Weight in Kgs  Age in Company            City
# 4    Benjamin           58.0            4.01         Fremont
# 8     Frances           42.0           23.27         Delmita
# 9       Diana           60.0            3.44  Eureka Springs
# 10      Ralph           80.0            8.29         Sabetha
# 11       Jack           61.0            0.56       Las Vegas
# ..        ...            ...             ...             ...
# 95       Jose           89.0            1.05          Biloxi
# 96     Harold           77.0            5.93    Carol Stream
# 97     Nicole           60.0           28.53         Detroit
# ...
