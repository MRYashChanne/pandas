# %% [markdown]
# # Pandas Functions
# - 1. df[col_name].value_counts()
#     - df[col_name].value_counts().to_dict()
# - 2. df[col_name].unique()
# - 3. df[col_name].nunique()
# - 4. df.replace()
# - 5. df.rename()
# - 6. df.astype()
# - 7. df.insert()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_demo = pd.DataFrame()
df_demo
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_demo["Testing_Col"] = [1,2,3,4,5]
df_demo
# Out:
#    Testing_Col
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Test'] = 1000

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Test
# 0      0         A/5 21171   7.2500   NaN        S  1000
# 1      0          PC 17599  71.2833   C85        C  1000
# 2      0  STON/O2. 3101282   7.9250   NaN        S  1000
# 3      0            113803  53.1000  C123        S  1000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Test         891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.386083    2.308642   29.699118    0.523008
# std     257.353842    0.487123    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare    Test
# count  891.000000  891.000000   891.0
# mean     0.381594   32.204208  1000.0
# std      0.806057   49.693429     0.0
# min      0.000000    0.000000  1000.0
# 25%      0.000000    7.910400  1000.0
# 50%      0.000000   14.454200  1000.0
# 75%      0.000000   31.000000  1000.0
# max      6.000000  512.329200  1000.0

# %% [markdown]
# # 1. value_counts()

# %%
df["Gender"].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df["PassengerId"].value_counts()
# Out:
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# # 2. unique()

# %%
df["Gender"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# # 3. nunique()

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Embarked"].nunique()
# Out:
# 3

# %% [markdown]
# # 4. series_to_dict

# %%
df["Gender"].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df["Gender"].value_counts().to_dict()
# Out:
# {'male': 577, 'female': 314}

# %% [markdown]
# # 5. replace()

# %%
df = pd.DataFrame(
    {
        "Values" : np.random.choice(["Male","Female"],10)
    }
)
df
# Out:
#    Values
# 0    Male
# 1    Male
# 2  Female
# 3    Male
# 4    Male
# 5  Female
# 6    Male
# 7  Female
# 8  Female
# 9    Male

# %%
df["Values"].value_counts()
# Out:
# Male      6
# Female    4
# Name: Values, dtype: int64

# %%
print(df)
df["Values"].replace({"Male":"Man" , "Female" : "Lady"},inplace=True)
df
# Out:
#    Values
# 0    Male
# 1    Male
# 2  Female
# 3    Male
# 4    Male
# 5  Female
# 6    Male
# 7  Female
# 8  Female
# 9    Male
#   Values
# 0    Man
# 1    Man
# 2   Lady
# 3    Man
# 4    Man
# 5   Lady
# 6    Man
# 7   Lady
# 8   Lady
# 9    Man

# %%
print(df)
df["Values"].replace({"Man":1 , "Lady" : 0},inplace=True)
df
# Out:
#   Values
# 0    Man
# 1    Man
# 2   Lady
# 3    Man
# 4    Man
# 5   Lady
# 6    Man
# 7   Lady
# 8   Lady
# 9    Man
#    Values
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
# 5       0
# 6       1
# 7       0
# 8       0
# 9       1

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Gender'].replace({"male":1,'female':0},inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina       0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].replace({"S":1,"C":2,"Q":3},inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina       0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # astype()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 83.7+ KB

# %%
df["Pclass"] = df["Pclass"].astype(float)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0     3.0
# 1              2         1     1.0
# 2              3         1     3.0
# 3              4         1     1.0
# 4              5         0     3.0
# ..           ...       ...     ...
# 886          887         0     2.0
# 887          888         1     1.0
# 888          889         0     3.0
# 889          890         1     1.0
# 890          891         0     3.0
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina       0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    float64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 83.7+ KB

# %%
df["SibSp"] = df["SibSp"].astype(object)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0     3.0
# 1              2         1     1.0
# 2              3         1     3.0
# 3              4         1     1.0
# 4              5         0     3.0
# ..           ...       ...     ...
# 886          887         0     2.0
# 887          888         1     1.0
# 888          889         0     3.0
# 889          890         1     1.0
# 890          891         0     3.0
#
#                                                   Name  Gender   Age SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0     1
# 2                               Heikkinen, Miss. Laina       0  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       0  35.0     1
# 4                             Allen, Mr. William Henry       1  35.0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    float64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    object
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 83.7+ KB

# %% [raw]
# int = str
# str = int (if string contains only integer values)

# %%
df_demo ** 2
# Out:
#    Testing_Col
# 0            1
# 1            4
# 2            9
# 3           16
# 4           25

# %%
df_demo["Testing_Col"] + 100
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: Testing_Col, dtype: int64

# %%
df_demo["Sq"] = df_demo["Testing_Col"] ** 2
df_demo["Cu"] = df_demo["Testing_Col"] ** 3
df_demo
# Out:
#    Testing_Col  Sq   Cu
# 0            1   1    1
# 1            2   4    8
# 2            3   9   27
# 3            4  16   64
# 4            5  25  125

# %%
df_demo["Just_Col"] = "Python"
df_demo
# Out:
#    Testing_Col  Sq   Cu Just_Col
# 0            1   1    1   Python
# 1            2   4    8   Python
# 2            3   9   27   Python
# 3            4  16   64   Python
# 4            5  25  125   Python

# %%
df_demo["New_Col"] = 10000
df_demo
# Out:
#    Testing_Col  Sq   Cu Just_Col  New_Col
# 0            1   1    1   Python    10000
# 1            2   4    8   Python    10000
# 2            3   9   27   Python    10000
# 3            4  16   64   Python    10000
# 4            5  25  125   Python    10000

# %%
Principle_Amount(P) = [100000,200000,500000,700000,10000000]
Interest_Rate(R) = [11,12,14,13,7]
Tenure(T) = [2,4,5,3,7]

Amount = P(1 + R / 100) ^ T
Coumpound_Interest = Amount - Principle_Amount

# %%
df = pd.DataFrame()
df["P"] = [100000,200000,500000,700000,10000000]
df["R"] = [11,12,14,13,7]
df["T"] = [2,4,5,3,7]
df["Amount"] = df["P"]*((1+(df["R"]/100))**df["T"])
df["Compound_interest"] = df["Amount"] - df["P"]
df
# Out:
#           P   R  T        Amount  Compound_interest
# 0    100000  11  2  1.232100e+05       2.321000e+04
# 1    200000  12  4  3.147039e+05       1.147039e+05
# 2    500000  14  5  9.627073e+05       4.627073e+05
# 3    700000  13  3  1.010028e+06       3.100279e+05
# 4  10000000   7  7  1.605781e+07       6.057815e+06

# %%
dict1 = {
    "Principle_Amount(P)": [100000,200000,500000,700000,10000000],
    "Interest_Rate(R)" : [11,12,14,13,7],
    "Tenure(T)" : [2,4,5,3,7]
}
df= pd.DataFrame(dict1)
df["Amount"]=df["Principle_Amount(P)"]*(1 + df["Interest_Rate(R)"] /100)**df["Tenure(T)"]
df["Coumpound_Interest"]= df["Amount"]- df["Principle_Amount(P)"]
df
# Out:
#    Principle_Amount(P)  Interest_Rate(R)  Tenure(T)        Amount  \
# 0               100000                11          2  1.232100e+05
# 1               200000                12          4  3.147039e+05
# 2               500000                14          5  9.627073e+05
# 3               700000                13          3  1.010028e+06
# 4             10000000                 7          7  1.605781e+07
#
#    Coumpound_Interest
# 0        2.321000e+04
# 1        1.147039e+05
# 2        4.627073e+05
# 3        3.100279e+05
# 4        6.057815e+06

# %% [markdown]
# # 8. insert()
# - df.insert(index_number , col_name, value , allow_duplicates = True/False)

# %%
df = pd.DataFrame()

# %%
df.insert(0,"A",[1,2,3,4,5])
df
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df.insert(0,"B",np.array([1,2,3,4,5])**2)
df
# Out:
#     B  A
# 0   1  1
# 1   4  2
# 2   9  3
# 3  16  4
# 4  25  5

# %%
df.insert(1,"C",np.array([1,2,3,4,5])**3)
df
# Out:
#     B    C  A
# 0   1    1  1
# 1   4    8  2
# 2   9   27  3
# 3  16   64  4
# 4  25  125  5

# %%
df.insert(3,"D",10000)
df
# Out:
#     B    C  A      D
# 0   1    1  1  10000
# 1   4    8  2  10000
# 2   9   27  3  10000
# 3  16   64  4  10000
# 4  25  125  5  10000

# %%
df.insert(3,"D",99)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-6636073f863e> in <module>
# ----> 1 df.insert(3,"D",99)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
# ...

# %%
df.insert(3,"D",99,allow_duplicates=True)
df
# Out:
#     B    C  A   D   D      D
# 0   1    1  1  99  99  10000
# 1   4    8  2  99  99  10000
# 2   9   27  3  99  99  10000
# 3  16   64  4  99  99  10000
# 4  25  125  5  99  99  10000

# %%
df["D"] = df['D'].apply(lambda n : n + 5)
df
# Out:
#     B    C  A    D    D      D
# 0   1    1  1  104  104  10005
# 1   4    8  2  104  104  10005
# 2   9   27  3  104  104  10005
# 3  16   64  4  104  104  10005
# 4  25  125  5  104  104  10005

# %%
df["E"] = df["A"] + df["B"]
df
# Out:
#     B    C  A    D    D      D   E
# 0   1    1  1  104  104  10005   2
# 1   4    8  2  104  104  10005   6
# 2   9   27  3  104  104  10005  12
# 3  16   64  4  104  104  10005  20
# 4  25  125  5  104  104  10005  30

# %%
df["F"] = (df["A"] + df["B"]) / 2
df
# Out:
#     B    C  A    D    D      D   E     F
# 0   1    1  1  104  104  10005   2   1.0
# 1   4    8  2  104  104  10005   6   3.0
# 2   9   27  3  104  104  10005  12   6.0
# 3  16   64  4  104  104  10005  20  10.0
# 4  25  125  5  104  104  10005  30  15.0

# %% [markdown]
# # 9. rename()

# %%
df
# Out:
#     B    C  A    D    D      D   E     F
# 0   1    1  1  104  104  10005   2   1.0
# 1   4    8  2  104  104  10005   6   3.0
# 2   9   27  3  104  104  10005  12   6.0
# 3  16   64  4  104  104  10005  20  10.0
# 4  25  125  5  104  104  10005  30  15.0

# %%
df.rename({"B":"BB"},inplace=True,axis=1)

# %%
df
# Out:
#    BB    C  A    D    D      D   E     F
# 0   1    1  1  104  104  10005   2   1.0
# 1   4    8  2  104  104  10005   6   3.0
# 2   9   27  3  104  104  10005  12   6.0
# 3  16   64  4  104  104  10005  20  10.0
# 4  25  125  5  104  104  10005  30  15.0

# %%
df.columns
# Out:
# Index(['BB', 'C', 'A', 'D', 'D', 'D', 'E', 'F'], dtype='object')

# %%
df.rename({"BB" : "BBB","C" : "CCC", "A":"AAA"},axis=1,inplace=True)
df
# Out:
#    BBB  CCC  AAA    D    D      D   E     F
# 0    1    1    1  104  104  10005   2   1.0
# 1    4    8    2  104  104  10005   6   3.0
# 2    9   27    3  104  104  10005  12   6.0
# 3   16   64    4  104  104  10005  20  10.0
# 4   25  125    5  104  104  10005  30  15.0

# %%
df.drop(['D', 'D', 'D', 'E', 'F'],axis=1,inplace=True)
df
# Out:
#    BBB  CCC  AAA
# 0    1    1    1
# 1    4    8    2
# 2    9   27    3
# 3   16   64    4
# 4   25  125    5

# %%
df.columns = list("ABC")
df
# Out:
#     A    B  C
# 0   1    1  1
# 1   4    8  2
# 2   9   27  3
# 3  16   64  4
# 4  25  125  5

# %%
df.index = list("PQRST")
df
# Out:
#     A    B  C
# P   1    1  1
# Q   4    8  2
# R   9   27  3
# S  16   64  4
# T  25  125  5

# %%
df.rename({"P":'p',"Q":"q","R":"r","S":"s","T":"t"},axis=0,inplace=True)
df
# Out:
#     A    B  C
# p   1    1  1
# q   4    8  2
# r   9   27  3
# s  16   64  4
# t  25  125  5

# %%
df.index = (100,200,300,400,500)
df
# Out:
#       A    B  C
# 100   1    1  1
# 200   4    8  2
# 300   9   27  3
# 400  16   64  4
# 500  25  125  5

# %%
df.index = [1,2,3,4,5]

# %%
df
# Out:
#     A    B  C
# 1   1    1  1
# 2   4    8  2
# 3   9   27  3
# 4  16   64  4
# 5  25  125  5

# %%
df.index = range(10,15)
df
# Out:
#      A    B  C
# 10   1    1  1
# 11   4    8  2
# 12   9   27  3
# 13  16   64  4
# 14  25  125  5

# %%
df.columns = range(0,3)
df
# Out:
#      0    1  2
# 10   1    1  1
# 11   4    8  2
# 12   9   27  3
# 13  16   64  4
# 14  25  125  5

# %%
df.columns = ["A","b","CC"]
df
# Out:
#      A    b  CC
# 10   1    1   1
# 11   4    8   2
# 12   9   27   3
# 13  16   64   4
# 14  25  125   5
