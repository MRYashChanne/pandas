# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Functions
# - 1. df.sort_index()
# - 2. df.sort_values()
# - 3. df.set_index()
# - 4. df.reset_index()

# %%
df = pd.read_csv("Emp_Records.csv")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# # 1. Sort_Index
# - axis = 0 > rows
# - axis = 1 > col

# %%
df.sort_index()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=1)
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36        Denver  677509       Lois  168251
# 1             9.01       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0              60
# 1              60
# 2              68
# 3              51
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=1,inplace=True)

# %%
df
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36        Denver  677509       Lois  168251
# 1             9.01       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0              60
# 1              60
# 2              68
# 3              51
# ...

# %%
df = pd.read_csv("Emp_Records.csv")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36        Denver  677509       Lois  168251
# 1             9.01       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0              60
# 1              60
# 2              68
# 3              51
# ...

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#     Weight in Kgs  Salary First Name  Emp ID          City  Age in Yrs  \
# 0              60  168251       Lois  677509        Denver       36.36
# 1              60   51063     Brenda  940761     Stonewall       47.02
# 2              68   50155        Joe  428945  Michigantown       54.15
# 3              51  180294      Diane  408351      Hydetown       39.67
# 4              58  117642   Benjamin  193819       Fremont       40.31
# ..            ...     ...        ...     ...           ...         ...
# 95             89  129774       Jose  639892        Biloxi       22.82
# 96             77  156194     Harold  704709  Carol Stream       32.61
# 97             60   95673     Nicole  461593       Detroit       52.66
# 98             57   51015    Theresa  392491      Mc Grath       29.60
# 99             55   93650      Tammy  495141          Alma       38.38
#
#     Age in Company
# 0            13.68
# 1             9.01
# 2             0.98
# 3            18.30
# ...

# %% [markdown]
# # 2. sort_values

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_values("First Name")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron       48.49             56           20.08   54402
# 43  247137       Alan       38.65             80           11.15  154810
# 41  227922     Amanda       35.02             40           10.28  114257
# 31  893212        Amy       36.14             52           14.17  112715
# 66  183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 17  214352    Theresa       24.66             59            2.52  197537
# 19  622406     Thomas       49.85             73           19.15   73862
# 64  917937       Todd       25.93             74            1.22  163560
# 13  301576      Wayne       21.10             87            0.02   92758
# 78  806955    William       50.05             50           17.36   73734
#
#             City
# 36       Eckerty
# 43     Knoxville
# 41  Lake Charles
# 31         Kline
# ...

# %%
df.sort_values("Salary")
# Out:
#     Emp ID   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 24  560455      Carolyn       59.42             53           16.08   42005
# 9   162402        Diana       29.73             60            3.44   43010
# 72  951225     Margaret       25.10             56            0.92   43867
# 60  687017      Frances       56.53             42            6.94   46945
# 79  325319      Carolyn       41.19             60            2.73   48736
# ..     ...          ...         ...            ...             ...     ...
# 71  478003      Cynthia       54.16             60           13.41  186200
# 42  265813         Jack       32.58             50           10.01  186280
# 55  253573       Sharon       26.25             43            3.39  190139
# 65  917395  Christopher       57.37             62           19.73  190765
# 17  214352      Theresa       24.66             59            2.52  197537
#
#               City
# 24     Saint Cloud
# 9   Eureka Springs
# ...

# %%
df.sort_values(["First Name","Weight in Kgs"])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron       48.49             56           20.08   54402
# 43  247137       Alan       38.65             80           11.15  154810
# 41  227922     Amanda       35.02             40           10.28  114257
# 31  893212        Amy       36.14             52           14.17  112715
# 66  183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 17  214352    Theresa       24.66             59            2.52  197537
# 19  622406     Thomas       49.85             73           19.15   73862
# 64  917937       Todd       25.93             74            1.22  163560
# 13  301576      Wayne       21.10             87            0.02   92758
# 78  806955    William       50.05             50           17.36   73734
#
#             City
# 36       Eckerty
# 43     Knoxville
# 41  Lake Charles
# 31         Kline
# ...

# %%
demo_df = pd.DataFrame(
    {
        "Numbers" : np.random.randint(1,10,10),
        "Alpha" : np.random.choice(list("ABCD"),10)
     }
)

# %%
demo_df
# Out:
#    Numbers Alpha
# 0        4     A
# 1        9     B
# 2        1     C
# 3        9     B
# 4        9     B
# 5        5     A
# 6        3     A
# 7        7     C
# 8        8     B
# 9        3     C

# %%
demo_df.sort_values(["Numbers","Alpha"])
# Out:
#    Numbers Alpha
# 2        1     C
# 6        3     A
# 9        3     C
# 0        4     A
# 5        5     A
# 7        7     C
# 8        8     B
# 1        9     B
# 3        9     B
# 4        9     B

# %%
demo_df.sort_values(["Alpha","Numbers"])
# Out:
#    Numbers Alpha
# 6        3     A
# 0        4     A
# 5        5     A
# 8        8     B
# 1        9     B
# 3        9     B
# 4        9     B
# 2        1     C
# 9        3     C
# 7        7     C

# %%
demo_df.sort_values("Alpha",ascending=False)
# Out:
#    Numbers Alpha
# 2        1     C
# 7        7     C
# 9        3     C
# 1        9     B
# 3        9     B
# 4        9     B
# 8        8     B
# 0        4     A
# 5        5     A
# 6        3     A

# %%
demo_df.sort_values(["Alpha","Numbers"],ascending=[True,False])
# Out:
#    Numbers Alpha
# 5        5     A
# 0        4     A
# 6        3     A
# 1        9     B
# 3        9     B
# 4        9     B
# 8        8     B
# 7        7     C
# 9        3     C
# 2        1     C

# %%
demo_df
# Out:
#    Numbers Alpha
# 0        4     A
# 1        9     B
# 2        1     C
# 3        9     B
# 4        9     B
# 5        5     A
# 6        3     A
# 7        7     C
# 8        8     B
# 9        3     C

# %%
demo_df.sort_values(["Alpha","Numbers"],ascending=[True,False],inplace=True)

# %%
demo_df
# Out:
#    Numbers Alpha
# 5        5     A
# 0        4     A
# 6        3     A
# 1        9     B
# 3        9     B
# 4        9     B
# 8        8     B
# 7        7     C
# 9        3     C
# 2        1     C

# %% [markdown]
# # 3. reset_index

# %%
df = pd.read_csv("Emp_Records.csv")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_values("First Name",inplace=True)

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron       48.49             56           20.08   54402
# 43  247137       Alan       38.65             80           11.15  154810
# 41  227922     Amanda       35.02             40           10.28  114257
# 31  893212        Amy       36.14             52           14.17  112715
# 66  183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 17  214352    Theresa       24.66             59            2.52  197537
# 19  622406     Thomas       49.85             73           19.15   73862
# 64  917937       Todd       25.93             74            1.22  163560
# 13  301576      Wayne       21.10             87            0.02   92758
# 78  806955    William       50.05             50           17.36   73734
#
#             City
# 36       Eckerty
# 43     Knoxville
# 41  Lake Charles
# 31         Kline
# ...

# %%
df.reset_index()
# Out:
#     index  Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# 0      36  218791      Aaron       48.49             56           20.08
# 1      43  247137       Alan       38.65             80           11.15
# 2      41  227922     Amanda       35.02             40           10.28
# 3      31  893212        Amy       36.14             52           14.17
# 4      66  183071     Andrea       32.08             52            7.28
# ..    ...     ...        ...         ...            ...             ...
# 95     17  214352    Theresa       24.66             59            2.52
# 96     19  622406     Thomas       49.85             73           19.15
# 97     64  917937       Todd       25.93             74            1.22
# 98     13  301576      Wayne       21.10             87            0.02
# 99     78  806955    William       50.05             50           17.36
#
#     Salary          City
# 0    54402       Eckerty
# 1   154810     Knoxville
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   218791      Aaron       48.49             56           20.08   54402
# 1   247137       Alan       38.65             80           11.15  154810
# 2   227922     Amanda       35.02             40           10.28  114257
# 3   893212        Amy       36.14             52           14.17  112715
# 4   183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 95  214352    Theresa       24.66             59            2.52  197537
# 96  622406     Thomas       49.85             73           19.15   73862
# 97  917937       Todd       25.93             74            1.22  163560
# 98  301576      Wayne       21.10             87            0.02   92758
# 99  806955    William       50.05             50           17.36   73734
#
#             City
# 0        Eckerty
# 1      Knoxville
# 2   Lake Charles
# 3          Kline
# ...

# %%
df.to_csv("Sorted_Emp_Df_ByName")

# %% [markdown]
# # 4. set_index

# %%
df.set_index("First Name")
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Aaron       218791       48.49             56           20.08   54402
# Alan        247137       38.65             80           11.15  154810
# Amanda      227922       35.02             40           10.28  114257
# Amy         893212       36.14             52           14.17  112715
# Andrea      183071       32.08             52            7.28   54179
# ...            ...         ...            ...             ...     ...
# Theresa     214352       24.66             59            2.52  197537
# Thomas      622406       49.85             73           19.15   73862
# Todd        917937       25.93             74            1.22  163560
# Wayne       301576       21.10             87            0.02   92758
# William     806955       50.05             50           17.36   73734
#
#                     City
# First Name
# Aaron            Eckerty
# Alan           Knoxville
# ...

# %%
df.set_index("City")
# Out:
#               Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# City
# Eckerty       218791      Aaron       48.49             56           20.08
# Knoxville     247137       Alan       38.65             80           11.15
# Lake Charles  227922     Amanda       35.02             40           10.28
# Kline         893212        Amy       36.14             52           14.17
# Granger       183071     Andrea       32.08             52            7.28
# ...              ...        ...         ...            ...             ...
# Toeterville   214352    Theresa       24.66             59            2.52
# Dutchtown     622406     Thomas       49.85             73           19.15
# Randallstown  917937       Todd       25.93             74            1.22
# Maida         301576      Wayne       21.10             87            0.02
# Mary Esther   806955    William       50.05             50           17.36
#
#               Salary
# City
# Eckerty        54402
# ...

# %%
drop_df = df.set_index("City",drop=True)
drop_df
# Out:
#               Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# City
# Eckerty       218791      Aaron       48.49             56           20.08
# Knoxville     247137       Alan       38.65             80           11.15
# Lake Charles  227922     Amanda       35.02             40           10.28
# Kline         893212        Amy       36.14             52           14.17
# Granger       183071     Andrea       32.08             52            7.28
# ...              ...        ...         ...            ...             ...
# Toeterville   214352    Theresa       24.66             59            2.52
# Dutchtown     622406     Thomas       49.85             73           19.15
# Randallstown  917937       Todd       25.93             74            1.22
# Maida         301576      Wayne       21.10             87            0.02
# Mary Esther   806955    William       50.05             50           17.36
#
#               Salary
# City
# Eckerty        54402
# ...

# %%
drop_df.index
# Out:
# Index(['Eckerty', 'Knoxville', 'Lake Charles', 'Kline', 'Granger', 'Arlee',
#        'Hancock', 'Cookeville', 'Stockholm', 'Mc Calla', 'Fremont', 'Mesa',
#        'Stonewall', 'Wright', 'Shreveport', 'Blanchester', 'Saint Cloud',
#        'Wheaton', 'Quecreek', 'Bays', 'Willow Beach', 'Oneida', 'Browning',
#        'Kansas City', 'Manning', 'Atqasuk', 'Blair', 'Eureka Springs',
#        'Hydetown', 'Lima', 'Philadelphia', 'Eckert', 'Rochester',
#        'Saranac Lake', 'Uniontown', 'Racine', 'Delmita', 'Trego', 'Bonanza',
#        'Carol Stream', 'Riverside', 'Las Vegas', 'Kalvesta', 'Miami',
#        'Whiteman Air Force Base', 'Hudson', 'Alcoa', 'Oriskany', 'Middleport',
#        'Michigantown', 'Biloxi', 'New Douglas', 'Ellsworth', 'Topeka',
#        'Eatontown', 'Primm Springs', 'Meno', 'East Saint Louis', 'Wichita',
#        'Panacea', 'Albion', 'Denver', 'Richmond Dale', 'Haswell',
#        'Lawrenceburg', 'Nardin', 'Conroy', 'Nashville', 'Heathsville',
# ...

# %%
ndrop_df = df.set_index("City",drop=False)
ndrop_df
# Out:
#               Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# City
# Eckerty       218791      Aaron       48.49             56           20.08
# Knoxville     247137       Alan       38.65             80           11.15
# Lake Charles  227922     Amanda       35.02             40           10.28
# Kline         893212        Amy       36.14             52           14.17
# Granger       183071     Andrea       32.08             52            7.28
# ...              ...        ...         ...            ...             ...
# Toeterville   214352    Theresa       24.66             59            2.52
# Dutchtown     622406     Thomas       49.85             73           19.15
# Randallstown  917937       Todd       25.93             74            1.22
# Maida         301576      Wayne       21.10             87            0.02
# Mary Esther   806955    William       50.05             50           17.36
#
#               Salary          City
# City
# ...

# %%
ndrop_df.index
# Out:
# Index(['Eckerty', 'Knoxville', 'Lake Charles', 'Kline', 'Granger', 'Arlee',
#        'Hancock', 'Cookeville', 'Stockholm', 'Mc Calla', 'Fremont', 'Mesa',
#        'Stonewall', 'Wright', 'Shreveport', 'Blanchester', 'Saint Cloud',
#        'Wheaton', 'Quecreek', 'Bays', 'Willow Beach', 'Oneida', 'Browning',
#        'Kansas City', 'Manning', 'Atqasuk', 'Blair', 'Eureka Springs',
#        'Hydetown', 'Lima', 'Philadelphia', 'Eckert', 'Rochester',
#        'Saranac Lake', 'Uniontown', 'Racine', 'Delmita', 'Trego', 'Bonanza',
#        'Carol Stream', 'Riverside', 'Las Vegas', 'Kalvesta', 'Miami',
#        'Whiteman Air Force Base', 'Hudson', 'Alcoa', 'Oriskany', 'Middleport',
#        'Michigantown', 'Biloxi', 'New Douglas', 'Ellsworth', 'Topeka',
#        'Eatontown', 'Primm Springs', 'Meno', 'East Saint Louis', 'Wichita',
#        'Panacea', 'Albion', 'Denver', 'Richmond Dale', 'Haswell',
#        'Lawrenceburg', 'Nardin', 'Conroy', 'Nashville', 'Heathsville',
# ...
