# %% [markdown]
# # Accessing Rows and Columns

# %%
import pandas as pd

# %%
emp_df = pd.read_csv("Emp_Records.csv")
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# # First N Rows

# %%
emp_df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
emp_df.head(10)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %% [markdown]
# # Last N Rows

# %%
emp_df.tail()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %%
emp_df.tail(10)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 90  185032     Eugene       37.84             59            2.64  122950
# 91  867084    Deborah       39.77             54           15.41   52767
# 92  969964     Janice       37.57             56            0.93  147641
# 93  158666    Rebecca       56.00             55           34.32  160043
# 94  489424    Phillip       39.43             82            1.56  181774
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#                        City
# 90                   Racine
# 91                  Atqasuk
# 92  Whiteman Air Force Base
# 93             Independence
# ...

# %% [markdown]
# # Access Columns

# %% [raw]
# df_name["Column Name"]
# df_name[Col_name_list]

# %%
emp_df.columns
# Out:
# Index(['Emp ID', 'First Name', 'Age in Yrs', 'Weight in Kgs', 'Age in Company',
#        'Salary', 'City'],
#       dtype='object')

# %%
emp_df["Emp ID"]
# Out:
# 0     677509
# 1     940761
# 2     428945
# 3     408351
# 4     193819
#        ...
# 95    639892
# 96    704709
# 97    461593
# 98    392491
# 99    495141
# Name: Emp ID, Length: 100, dtype: int64

# %%
type(emp_df["Emp ID"])
# Out:
# pandas.core.series.Series

# %%
emp_df[["Emp ID"]]
# Out:
#     Emp ID
# 0   677509
# 1   940761
# 2   428945
# 3   408351
# 4   193819
# ..     ...
# 95  639892
# 96  704709
# 97  461593
# 98  392491
# 99  495141
#
# [100 rows x 1 columns]

# %%
type(emp_df[["Emp ID"]])
# Out:
# pandas.core.frame.DataFrame

# %%
emp_df[['First Name']]
# Out:
#    First Name
# 0        Lois
# 1      Brenda
# 2         Joe
# 3       Diane
# 4    Benjamin
# ..        ...
# 95       Jose
# 96     Harold
# 97     Nicole
# 98    Theresa
# 99      Tammy
#
# [100 rows x 1 columns]

# %%
emp_df.columns
# Out:
# Index(['Emp ID', 'First Name', 'Age in Yrs', 'Weight in Kgs', 'Age in Company',
#        'Salary', 'City'],
#       dtype='object')

# %%
emp_df[['First Name',"Salary","City"]]
# Out:
#    First Name  Salary          City
# 0        Lois  168251        Denver
# 1      Brenda   51063     Stonewall
# 2         Joe   50155  Michigantown
# 3       Diane  180294      Hydetown
# 4    Benjamin  117642       Fremont
# ..        ...     ...           ...
# 95       Jose  129774        Biloxi
# 96     Harold  156194  Carol Stream
# 97     Nicole   95673       Detroit
# 98    Theresa   51015      Mc Grath
# 99      Tammy   93650          Alma
#
# [100 rows x 3 columns]

# %%
new_df = emp_df[['First Name',"City","Salary"]]
new_df
# Out:
#    First Name          City  Salary
# 0        Lois        Denver  168251
# 1      Brenda     Stonewall   51063
# 2         Joe  Michigantown   50155
# 3       Diane      Hydetown  180294
# 4    Benjamin       Fremont  117642
# ..        ...           ...     ...
# 95       Jose        Biloxi  129774
# 96     Harold  Carol Stream  156194
# 97     Nicole       Detroit   95673
# 98    Theresa      Mc Grath   51015
# 99      Tammy          Alma   93650
#
# [100 rows x 3 columns]

# %% [markdown]
# # Slicing Method

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df[0:5]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
emp_df[10:55]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 10  231469      Ralph       42.50             80            8.29  118457
# 11  153989       Jack       22.21             61            0.56   82965
# 12  386158    Melissa       45.45             55            1.68  166892
# 13  301576      Wayne       21.10             87            0.02   92758
# 14  441771     Cheryl       59.47             47           26.69   92220
# 15  528509      Paula       50.97             42           22.95  152654
# 16  912990     Joshua       47.23             68           14.91  184896
# 17  214352    Theresa       24.66             59            2.52  197537
# 18  890290      Julia       58.08             56           12.43  141518
# 19  622406     Thomas       49.85             73           19.15   73862
# 20  979607      Carol       22.64             56            1.26   93967
# 21  969580    Matthew       23.77             56            1.47   52237
# ...

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   100 non-null    int64
#  4   Age in Company  100 non-null    float64
#  5   Salary          100 non-null    int64
#  6   City            100 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 5.6+ KB

# %%
emp_df[99:]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  City
# 99  495141      Tammy       38.38             55            2.26   93650  Alma

# %% [markdown]
# # iloc[]
# - df.iloc[row_index, col_index]

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.iloc[:,:]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.iloc[2:5,:]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
emp_df.iloc[2:5,1:4]
# Out:
#   First Name  Age in Yrs  Weight in Kgs
# 2        Joe       54.15             68
# 3      Diane       39.67             51
# 4   Benjamin       40.31             58

# %%
emp_df.iloc[2:5,4:]
# Out:
#    Age in Company  Salary          City
# 2            0.98   50155  Michigantown
# 3           18.30  180294      Hydetown
# 4            4.01  117642       Fremont

# %%
emp_df.iloc[5:2:-1,:]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 5  499687    Patrick       34.86             58           12.02   72305
# 4  193819   Benjamin       40.31             58            4.01  117642
# 3  408351      Diane       39.67             51           18.30  180294
#
#         City
# 5  Macksburg
# 4    Fremont
# 3   Hydetown

# %%
emp_df.iloc[[0,2,3],[1,4]]
# Out:
#   First Name  Age in Company
# 0       Lois           13.68
# 2        Joe            0.98
# 3      Diane           18.30

# %% [markdown]
# # loc
# - df.loc[Row_Lable, Col_Name]

# %%
emp_df.loc[:,:]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.loc[2:5,:]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
#
#            City
# 2  Michigantown
# 3      Hydetown
# 4       Fremont
# 5     Macksburg

# %%
emp_df.loc[2:5,"Emp ID"]
# Out:
# 2    428945
# 3    408351
# 4    193819
# 5    499687
# Name: Emp ID, dtype: int64

# %%
emp_df.loc[2:5,"First Name":"Salary"]
# Out:
#   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary
# 2        Joe       54.15             68            0.98   50155
# 3      Diane       39.67             51           18.30  180294
# 4   Benjamin       40.31             58            4.01  117642
# 5    Patrick       34.86             58           12.02   72305

# %%
emp_df.loc[[1,4,6,7,90],["First Name","Age in Yrs","Salary"]]
# Out:
#    First Name  Age in Yrs  Salary
# 1      Brenda       47.02   51063
# 4    Benjamin       40.31  117642
# 6       Nancy       22.14   98189
# 7       Carol       59.12   60918
# 90     Eugene       37.84  122950
